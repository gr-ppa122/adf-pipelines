# %%
dbutils.fs.mount(
  source = "wasbs://staging@sappa122.blob.core.windows.net",
  mount_point = "/mnt/staging",
  extra_configs = {"fs.azure.account.key.sappa122.blob.core.windows.net":dbutils.secrets.get(scope = "azdbscopeppa122", key = "blobkey")})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-45152117289875&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>   source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;wasbs://staging@sappa122.blob.core.windows.net&#34;</span><span class="ansi-blue-fg">,</span>
# ...

# %%
# %fs ls /mnt/staging/YearlySales.csv
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/staging/YearlySales.csv</td><td>YearlySales.csv</td><td>355</td></tr></tbody></table></div>

# %%
path = "/mnt/staging/YearlySales.csv"
data = sc.textFile(path)
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: 21</div>

# %%
datalog = sc.textFile(path).cache()
datalog.take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [&#39;Order_id,Country,Year,Sales&#39;,
#  &#39;1,USA,2015,729&#39;,
#  &#39;2,USA,2016,645&#39;,
#  &#39;3,USA,2017,735&#39;,
#  &#39;4,USA,2018,605&#39;,
#  &#39;5,USA,2019,533&#39;,
#  &#39;6,UK,2015,697&#39;,
#  &#39;7,UK,2016,631&#39;,
#  &#39;8,UK,2017,680&#39;,
#  &#39;9,UK,2018,560&#39;]</div>

# %%
USAcnt = datalog.filter(lambda s: 'USA' in s.lower()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DirPath = "/mnt/staging/*.csv"
files = sc.wholeTextFiles(path)
files.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 1</div>

# %%
filnames = files.toDF(['filename','data'])
display(filnames)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>filename</th><th>data</th></tr></thead><tbody><tr><td>dbfs:/mnt/staging/YearlySales.csv</td><td>Order_id,Country,Year,Sales
# 1,USA,2015,729
# 2,USA,2016,645
# 3,USA,2017,735
# 4,USA,2018,605
# 5,USA,2019,533
# 6,UK,2015,697
# 7,UK,2016,631
# 8,UK,2017,680
# 9,UK,2018,560
# 10,UK,2019,608
# 11,IND,2015,527
# 12,IND,2016,505
# 13,IND,2017,650
# 14,IND,2018,552
# 15,IND,2019,543
# 16,AUZ,2015,600
# 17,AUZ,2016,729
# 18,AUZ,2017,684
# 19,AUZ,2018,747
# 20,AUZ,2019,693
# </td></tr></tbody></table></div>

# %%
Ysdata = spark.read.csv(path)
Ysdata.take(10)
type(Ysdata)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: pyspark.sql.dataframe.DataFrame</div>

# %%
df = spark.read.load(path,
                    format = 'com.databricks.spark.csv',
                    header = "true",
                    inferSchema = "true")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+-------+----+-----+
# Order_id|Country|Year|Sales|
# +--------+-------+----+-----+
#        1|    USA|2015|  729|
#        2|    USA|2016|  645|
#        3|    USA|2017|  735|
#        4|    USA|2018|  605|
#        5|    USA|2019|  533|
#        6|     UK|2015|  697|
#        7|     UK|2016|  631|
#        8|     UK|2017|  680|
#        9|     UK|2018|  560|
#       10|     UK|2019|  608|
#       11|    IND|2015|  527|
#       12|    IND|2016|  505|
#       13|    IND|2017|  650|
#       14|    IND|2018|  552|
#       15|    IND|2019|  543|
#       16|    AUZ|2015|  600|
#       17|    AUZ|2016|  729|
# ...

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Order_id: integer (nullable = true)
# -- Country: string (nullable = true)
# -- Year: integer (nullable = true)
# -- Sales: integer (nullable = true)
#
# </div>

# %%
df.select("Country").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+
# Country|
# +-------+
#     USA|
#     USA|
#     USA|
#     USA|
#     USA|
#      UK|
#      UK|
#      UK|
#      UK|
#      UK|
#     IND|
#     IND|
#     IND|
#     IND|
#     IND|
#     AUZ|
#     AUZ|
#     AUZ|
#     AUZ|
#     AUZ|
# +-------+
#
# </div>
